# %%
import pandas as pd
import altair as alt

# %%
# import scraped csv to pandas df
briefings_df = pd.read_csv('../data/cleaned_briefings.csv')
briefings_df
# Out:
#             date timestamp             speaker  \
# 0     2020-02-26     05:39        Donald Trump
# 1     2020-02-26     06:59        Donald Trump
# 2     2020-02-26     07:51        Donald Trump
# 3     2020-02-26     09:58        Donald Trump
# 4     2020-02-26     10:52        Donald Trump
# ...          ...       ...                 ...
# 9674  2020-04-27  01:01:23  Unnamed (Reporter)
# 9675  2020-04-27  01:01:24        Donald Trump
# 9676  2020-04-27  01:01:26             Unnamed
# 9677  2020-04-27  01:01:36        Donald Trump
# 9678  2020-04-27  01:02:17        Donald Trump
#
#                                                    text
# 0     Thank you very much everybody. Thank you very ...
# 1     A lot of people thought we shouldn’t have done...
# 2     We have a total of 15. We took in some from Ja...
# 3     China you know about. Where it started. I spok...
# 4     We’re bringing in a specialist, a very highly ...
# ...                                                 ...
# 9674                              [crosstalk 00:13:23].
# 9675            Let’s do one more. Please, in the back.
# 9676  If an American president loses more Americans ...
# 9677  So yeah, we’ve lost a lot of people, but if yo...
# 9678  The press doesn’t talk about ventilators anymo...
#
# [9679 rows x 4 columns]

# %% [markdown]
# ### Emotion Analysis using the NRC Emotion Lexicon
#
# - Rather than using just the simple TextBlob or Vader packages for sentiment analysis, I thought it would be interesting to explore emotional tone using
# - Let's see what we can uncover using the popular open-sourced emotion lexicon published by the NRC (National Research Council Canada).
# - In addition to 'positive' and 'negative', we have word associations for 8 overarching emotion categories.
# - For simplicity, let's remove words without scores as well as those that are associated with 8 or more of the 10 categories

# %%
# read in raw emotion lexicon
filepath = "../NRC-Sentiment-Emotion-Lexicons/NRC-Emotion-Lexicon-v0.92/NRC-Emotion-Lexicon-Wordlevel-v0.92.txt"
emolex_df = pd.read_csv(filepath,  names=["word", "emotion", "association"], skiprows=1, sep='\t')

# pivot df so we have one row per word, one column per emotion
emolex_df = emolex_df.pivot(index='word', columns='emotion', values='association').reset_index()

# rename df column
emolex_df.columns.name = 'index'

# filter out words without scores and with more than 7 scores
emolex_df = emolex_df[emolex_df.sum(axis=1)>0].reset_index(drop=True)
emolex_df = emolex_df[emolex_df.sum(axis=1)<7].reset_index(drop=True)
emolex_df
# Out:
# index         word  anger  anticipation  disgust  fear  joy  negative  \
# 0           abacus      0             0        0     0    0         0
# 1          abandon      0             0        0     1    0         1
# 2        abandoned      1             0        0     1    0         1
# 3      abandonment      1             0        0     1    0         1
# 4             abba      0             0        0     0    0         0
# ...            ...    ...           ...      ...   ...  ...       ...
# 6437          zany      0             0        0     0    0         0
# 6438          zeal      0             1        0     0    1         0
# 6439       zealous      0             0        0     0    1         0
# 6440          zest      0             1        0     0    1         0
# 6441           zip      0             0        0     0    0         1
#
# index  positive  sadness  surprise  trust
# 0             0        0         0      1
# 1             0        1         0      0
# 2             0        1         0      0
# 3             0        1         1      0
# 4             1        0         0      0
# ...         ...      ...       ...    ...
# 6437          0        0         1      0
# 6438          1        0         1      1
# 6439          1        0         0      1
# 6440          1        0         0      1
# 6441          0        0         0      0
#
# [6442 rows x 11 columns]

# %% [markdown]
# #### Using this lexicon, we can now we can now easily lookup all words from a single paragraph of the corpus:

# %%
paragraph_words = briefings_df.text[500].split()
emolex_df[pd.DataFrame(emolex_df.word.tolist()).isin(paragraph_words).any(1)]
# Out:
# index       word  anger  anticipation  disgust  fear  joy  nrc_negative  \
# 1238         big      0             0        0     0    0             0
# 1811        care      0             0        0     0    0             0
# 3088         cut      0             0        0     0    0             0
# 5094       force      1             0        0     1    0             1
# 6334   important      0             0        0     0    0             0
# 7759      matter      0             0        0     0    0             0
# 7814     meeting      0             0        0     0    0             0
# 9956      public      0             1        0     0    0             0
# 12549       task      0             0        0     0    0             0
# 12563        tax      0             0        0     0    0             1
# 13742      virus      0             0        0     0    0             1
#
# index  nrc_positive  sadness  surprise  trust
# 1238              0        0         0      0
# 1811              0        0         0      0
# 3088              0        0         0      0
# 5094              0        0         0      0
# 6334              1        0         0      1
# 7759              0        0         0      0
# 7814              0        0         0      0
# 9956              1        0         0      0
# 12549             1        0         0      0
# 12563             0        1         0      0
# 13742             0        0         0      0

# %% [markdown]
# #### Let's calculate and store aggregate emotion scores for each paragraph in the corpus:

# %%
# create empty df to store aggregated emotion calcs
data = pd.DataFrame([])

for text in briefings_df['text']:
    paragraph_words = text.split()
    paragraph_emos = emolex_df[pd.DataFrame(emolex_df.word.tolist()).isin(paragraph_words).any(1)].mean()
    data = data.append(paragraph_emos, ignore_index=True)
    
# combine aggregated emotion scores with transcript df
briefings_df = briefings_df.join(data)

# drop empty 'word' column, fill NaNs with zero
briefings_df = briefings_df.drop(columns=['word'])
briefings_df = briefings_df.fillna(0)

briefings_df
# Out:
#             date timestamp             speaker  \
# 0     2020-02-26     05:39        Donald Trump
# 1     2020-02-26     06:59        Donald Trump
# 2     2020-02-26     07:51        Donald Trump
# 3     2020-02-26     09:58        Donald Trump
# 4     2020-02-26     10:52        Donald Trump
# ...          ...       ...                 ...
# 9674  2020-04-27  01:01:23  Unnamed (Reporter)
# 9675  2020-04-27  01:01:24        Donald Trump
# 9676  2020-04-27  01:01:26             Unnamed
# 9677  2020-04-27  01:01:36        Donald Trump
# 9678  2020-04-27  01:02:17        Donald Trump
#
#                                                    text     anger  \
# 0     Thank you very much everybody. Thank you very ...  0.136364
# 1     A lot of people thought we shouldn’t have done...  0.055556
# 2     We have a total of 15. We took in some from Ja...  0.000000
# 3     China you know about. Where it started. I spok...  0.142857
# 4     We’re bringing in a specialist, a very highly ...  0.000000
# ...                                                 ...       ...
# 9674                              [crosstalk 00:13:23].  0.000000
# 9675            Let’s do one more. Please, in the back.  0.000000
# 9676  If an American president loses more Americans ...  0.333333
# 9677  So yeah, we’ve lost a lot of people, but if yo...  0.071429
# 9678  The press doesn’t talk about ventilators anymo...  0.000000
#
#       anticipation   disgust      fear       joy  nrc_negative  nrc_positive  \
# 0         0.136364  0.090909  0.181818  0.090909      0.272727      0.181818
# 1         0.222222  0.111111  0.166667  0.055556      0.166667      0.222222
# 2         0.130435  0.000000  0.043478  0.173913      0.000000      0.391304
# 3         0.214286  0.000000  0.142857  0.214286      0.214286      0.357143
# 4         0.153846  0.000000  0.076923  0.076923      0.230769      0.153846
# ...            ...       ...       ...       ...           ...           ...
# 9674      0.000000  0.000000  0.000000  0.000000      0.000000      0.000000
# 9675      0.000000  0.000000  0.000000  0.000000      0.000000      0.000000
# 9676      0.333333  0.000000  0.000000  0.000000      0.000000      0.666667
# 9677      0.142857  0.000000  0.071429  0.071429      0.142857      0.214286
# 9678      0.111111  0.000000  0.000000  0.000000      0.111111      0.333333
#
#        sadness  surprise     trust
# 0     0.136364  0.090909  0.090909
# 1     0.055556  0.055556  0.166667
# 2     0.043478  0.086957  0.217391
# 3     0.000000  0.071429  0.214286
# 4     0.076923  0.000000  0.153846
# ...        ...       ...       ...
# 9674  0.000000  0.000000  0.000000
# 9675  0.000000  0.000000  0.000000
# 9676  0.000000  0.000000  0.666667
# 9677  0.071429  0.071429  0.071429
# 9678  0.000000  0.000000  0.000000
#
# [9679 rows x 14 columns]

# %%
# save scores df to csv
briefings_df.to_csv("../data/scored_briefings.csv",index=False)

# %%
briefings_df[briefings_df.sum(axis=1) > 5]
# Out:
#             date timestamp          speaker  \
# 48    2020-02-26     33:52     Donald Trump
# 1749  2020-03-19     39:28  John (Reporter)
# 1910  2020-03-19  01:12:19     Donald Trump
# 2845  2020-03-23     56:03     Donald Trump
# 3867  2020-03-29  01:10:03          Unnamed
# 4126  2020-03-31     37:03          Unnamed
# 4937  2020-04-02  01:22:02     Journalist 5
# 5590  2020-04-04  01:42:42     Donald Trump
# 6352  2020-04-07     54:09     Donald Trump
# 6551  2020-04-08     33:08     Donald Trump
# 7375  2020-04-13  01:16:30          Unnamed
# 8486  2020-04-19  01:17:15          Unnamed
#
#                                                    text     anger  \
# 48    Our consumers are incredible, they’re incredib...  1.000000
# 1749  You can say that none of this money can go for...  1.000000
# 1910               They treat me very nicely. Go ahead.  1.000000
# 2845  Death from the death, you’re talking about dea...  0.500000
# 3867  Thank you, sir. I’d also like to ask you about...  1.000000
# 4126  But doctor, when we look at the curve, it goes...  0.500000
# 4937                 What do you mean by cash payments?  1.000000
# 5590  Both. Some states are doing when they land, th...  1.000000
# 6352                        You just said death counts?  1.000000
# 6551  I had a feeling it was done. Is that what he s...  1.000000
# 7375  Have you figured out the bail-out money for th...  1.000000
# 8486  You know, you referred these protests in earli...  0.666667
#
#       anticipation   disgust      fear       joy  nrc_negative  nrc_positive  \
# 48        1.000000  1.000000  1.000000  1.000000      0.000000      1.000000
# 1749      1.000000  0.000000  0.000000  1.000000      0.000000      1.000000
# 1910      1.000000  1.000000  1.000000  1.000000      1.000000      1.000000
# 2845      1.000000  0.500000  0.500000  0.500000      0.500000      0.500000
# 3867      1.000000  1.000000  1.000000  1.000000      1.000000      1.000000
# 4126      1.000000  0.500000  0.500000  0.000000      0.500000      0.500000
# 4937      1.000000  0.000000  1.000000  1.000000      0.000000      1.000000
# 5590      1.000000  1.000000  1.000000  1.000000      0.000000      1.000000
# 6352      1.000000  1.000000  1.000000  0.000000      1.000000      0.000000
# 6551      1.000000  1.000000  1.000000  1.000000      1.000000      1.000000
# 7375      1.000000  0.000000  0.000000  1.000000      0.000000      1.000000
# 8486      0.666667  0.666667  0.666667  0.666667      0.666667      0.666667
#
#        sadness  surprise     trust
# 48    0.000000  0.000000  1.000000
# 1749  0.000000  1.000000  1.000000
# 1910  1.000000  1.000000  1.000000
# 2845  0.500000  0.500000  0.500000
# 3867  1.000000  1.000000  1.000000
# 4126  0.500000  1.000000  0.500000
# 4937  0.000000  0.000000  1.000000
# 5590  0.000000  0.000000  1.000000
# 6352  1.000000  1.000000  0.000000
# 6551  1.000000  1.000000  1.000000
# 7375  0.000000  1.000000  1.000000
# 8486  0.333333  0.666667  0.666667
